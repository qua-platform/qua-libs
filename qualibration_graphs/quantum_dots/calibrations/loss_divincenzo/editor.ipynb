# %%
from quam_builder.architecture.quantum_dots.qpu import LossDiVincenzoQuam
machine = LossDiVincenzoQuam.load("/Users/kalidu_laptop/Tutorial_Quam_State")
# Out:
# 2026-06-25 11:17:14,227 - qm - INFO     - Starting session: 38af892c-448d-49de-8162-43ded36f2ace
# /Users/kalidu_laptop/sig_eval/eval/lib/python3.12/site-packages/quam/core/quam_classes.py:639: UserWarning: No QuamRoot initialized, cannot retrieve absolute reference #/wiring/readout/s1/rf/opx_output from ReadoutResonatorSingle
#   warnings.warn(
# /Users/kalidu_laptop/sig_eval/eval/lib/python3.12/site-packages/quam/core/quam_classes.py:639: UserWarning: No QuamRoot initialized, cannot retrieve absolute reference #/wiring/readout/s2/rf/opx_output from ReadoutResonatorSingle
#   warnings.warn(
# /Users/kalidu_laptop/sig_eval/eval/lib/python3.12/site-packages/quam/core/quam_classes.py:639: UserWarning: No QuamRoot initialized, cannot retrieve absolute reference #/quantum_dots from QuamList
#   warnings.warn(
# ...

# %%
machine.qubits['q1'].larmor_frequency
# Out:
# 17985000000.0

# %%
q1 = machine.qubits["q1"]
q1.xy.opx_output.upconverter_frequency
# Out:
# 8000000000.0
